# %%
import pandas as pd

# %%
sui_diagnosis = pd.read_csv("sui_diagnosis.csv", header=0)

# %%
pd.set_option("display.max_colwidth", 10000)
print(list(sui_diagnosis["diagnosisstring"]))
# Out:
# ['toxicology|drug overdose|drug overdose- general|previous suicide attempts', 'toxicology|drug overdose|drug overdose- general|suicide attempt', 'toxicology|drug overdose|drug overdose- general|previous suicide attempts', 'toxicology|drug overdose|drug overdose- general|suicide gesture', 'neurologic|altered mental status / pain|suicidal ideation', 'neurologic|altered mental status / pain|suicidal ideation', 'neurologic|altered mental status / pain|suicidal ideation', 'toxicology|drug overdose|drug overdose- general|previous suicide attempts', 'toxicology|drug overdose|drug overdose- general|suicide gesture', 'toxicology|drug overdose|drug overdose- general|previous suicide attempts', 'toxicology|drug overdose|drug overdose- general|previous suicide attempts', 'toxicology|drug overdose|drug overdose- general|suicide gesture', 'toxicology|drug overdose|drug overdose- general|suicide gesture', 'toxicology|drug overdose|drug overdose- general|suicide attempt', 'toxicology|drug overdose|d
# ...

# %%
diagnosis = pd.read_csv("/home/cs52205/diagnosis.csv.gz", compression="gzip", header=0)

# %%
result = list(diagnosis["diagnosisstring"].unique())

# %%
#print(result)

# %%
import re
re_pattern = r"\b(?:suicide|ideation)\b"
re.findall(re_pattern, result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-1e49aaa7cc3b> in <module>()
#       1 import re
#       2 re_pattern = r"\b(?:suicide|ideation)\b"
# ----> 3 re.findall(re_pattern, result)
#
# /home/cs52205/anaconda2/lib/python2.7/re.pyc in findall(pattern, string, flags)
#     179
#     180     Empty matches are included in the result."""
# --> 181     return _compile(pattern, flags).findall(string)
#     182
#     183 if sys.hexversion >= 0x02020000:
#
# TypeError: expected string or buffer

# %%
sui_admissionDx = pd.read_csv("sui_admissionDx.csv")

# %%
print(sui_admissionDx["admitdxpath"].unique())
# Out:
# ['admission diagnosis|All Diagnosis|Non-operative|Diagnosis|Neurology|Overdose, analgesic (aspirin, acetaminophen)'
#  'admission diagnosis|Non-operative Organ Systems|Organ System|Neurologic'
#  'admission diagnosis|Was the patient admitted from the O.R. or went to the O.R. within 4 hours of admission?|No'
#  'admission diagnosis|All Diagnosis|Non-operative|Diagnosis|Neurology|Overdose, sedatives, hypnotics, antipsychotics, benzodiazepines'
#  'admission diagnosis|All Diagnosis|Non-operative|Diagnosis|Trauma|Head only trauma'
#  'admission diagnosis|Non-operative Organ Systems|Organ System|Trauma'
#  'admission diagnosis|All Diagnosis|Non-operative|Diagnosis|Neurology|Seizures (primary-no structural brain disease)'
#  'admission diagnosis|All Diagnosis|Non-operative|Diagnosis|Neurology|Overdose, antidepressants (cyclic, lithium)'
#  'admission diagnosis|Non-operative Organ Systems|Organ System|Cardiovascular'
# ...
